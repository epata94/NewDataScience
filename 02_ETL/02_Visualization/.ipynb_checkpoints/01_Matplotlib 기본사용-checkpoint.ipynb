# %% [markdown]
# ## 기본 그래프

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 쥬피터 노트북에서 시작화 화면을 확인 가능하게 하는 명령
# %matplotlib inline

# %% [raw]
# pyplot.plot() 함수에 하나의 숫자 리스트를 입력함으로써 아래와 같은 그래프가 그려집니다.
#
# plot() 함수는 리스트의 값들이 y 값들이라고 가정하고, x 값 [0, 1, 2, 3]을 자동으로 만들어냅니다.
#
# matplotlib.pyplot 모듈의 show() 함수는 그래프를 화면에 나타나도록 합니다.

# %% [markdown]
# ### 데이터 입력

# %%
# (0,1),(1,2),(2,3),(3,4) 좌표와 매치
plt.plot([1, 2, 3, 4])
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %% [markdown]
# ## 스타일 지정

# %%
                                     #  <= Format String
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro')
# axis 함수로 축의 범위 지정 [xmin, xmax, ymin, ymax]
plt.axis([0, 6, 0, 20])
plt.show()

# %% [markdown]
# ## 여러 개의 그래프 그리기

# %%
import numpy as np
t = np.arange(0., 5., 0.2)
# 0에서 5사이 0.2씩 증가
t
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4,
#        2.6, 2.8, 3. , 3.2, 3.4, 3.6, 3.8, 4. , 4.2, 4.4, 4.6, 4.8])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 빨간 대쉬, 파란 사각형, 녹색 삼각형
# 포멧스트링의 첫번째 글자는 색깔, 두번째 글자는 모양을 의미함
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# ## 변수 활용

# %%
data_dict = {'data_x': [1, 2, 3, 4, 5], 'data_y': [2, 3, 5, 10, 8]}

plt.plot('data_x', 'data_y', data=data_dict)
plt.show()

# %% [markdown]
# ## 축 설정
# ### 레이블 사용

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
# X축 레벨
plt.xlabel('X-Label')
# Y축 레벨
plt.ylabel('Y-Label')
plt.show()

# %% [markdown]
# ### 여백 설정

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# labelpad 인자로 여백 지정 (단위 pt)
plt.xlabel('X-Axis', labelpad=15)
plt.ylabel('Y-Axis', labelpad=20)
plt.show()

# %% [markdown]
# ### 폰트 설정

# %%
font1 = {'family': 'serif',
         'color': 'b',
         'weight': 'bold',
         'size': 14
         }

font2 = {'family': 'fantasy',
         'color': 'deeppink',
         'weight': 'normal',
         'size': 'xx-large'
         }

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis', labelpad=15, fontdict=font1)
plt.ylabel('Y-Axis', labelpad=20, fontdict=font2)
plt.show()

# %% [markdown]
# ### 위치 설정

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
# x축 레이블 위치 지정 (‘left’, ‘center’, ‘right’)
plt.xlabel('X-Axis', loc='right')
# y축 레이블 위치 지정 (‘bottom’, ‘center’, ‘top’)
plt.ylabel('Y-Axis', loc='top')
plt.show()
# 변경해 보세요.

# %% [markdown]
# ## 범례 표시하기

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Step1: label에 범례명을 입력한다.
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# Step2: legend함수를 호출한다.
plt.legend()

plt.show()

# %% [markdown]
# ### 범례 위치 지정

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# 좌측하단
# 값은 비율로 입력
# plt.legend(loc=(0.0, 0.0))
# 중간
# plt.legend(loc=(0.5, 0.5))
# 우측상단
plt.legend(loc=(1.0, 1.0))

plt.show()

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# lower/upper와 left/right의 조합으로 표현
plt.legend(loc='lower right')

plt.show()

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.legend(loc='upper left')

plt.show()

# %% [markdown]
# ## 열개수 지정

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# loc='best' 최적의 공간을 찾아준다. 디폴트 옵션은 1열로 범례를 표시한다.
# plt.legend(loc='best')          # ncol = 1
#2열로 범례를 표시한다.
plt.legend(loc='best', ncol=2)    # ncol = 2

plt.show()

# %% [markdown]
# ### 폰트 크기 지정하기

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc='best')
plt.legend(loc='best', ncol=2, fontsize=14)

plt.show()

# %% [markdown]
# # 한글 폰트 지정

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='가격 (원)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='공급 (#)')
# 한글 입력시 별도의 설정이 없으면 깨져서 나옴
plt.xlabel('y-축')
plt.ylabel('x-축')
# plt.legend(loc='best')
plt.legend(loc='best', ncol=2, fontsize=14)

plt.show()

# %%
from matplotlib import font_manager,rc

# %%
font_location = "C:\Windows\Fonts\malgun.ttf"
font_name = font_manager.FontProperties(fname=font_location).get_name()
rc('font',family=font_name)

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc='best')
plt.legend(loc='best', ncol=2, fontsize=14)
plt.xlabel('X축 라벨')
plt.ylabel('Y축 라벨')
plt.show()

# %% [markdown]
# ### 범례 테두리

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10], label='Price ($)')
plt.plot([1, 2, 3, 4], [3, 5, 9, 7], label='Demand (#)')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.legend(loc='best')
# frameon: 테두리 생성여부 (기본값이 True)
# shadow: 텍스트 상자에 그림자 여부
plt.legend(loc='best', ncol=2, fontsize=14, frameon=True, shadow=True)

plt.show()

# %% [markdown]
# ### 축 범위

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.xlim([0, 5])      # X축의 범위: [xmin, xmax]
plt.ylim([0, 12])     # Y축의 범위: [ymin, ymax]

plt.show()

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0, 5, 0, 12])  # X, Y축의 범위: [xmin, xmax, ymin, ymax]

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis('square')
# plt.axis('scaled')

plt.show()

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
# plt.axis('square')
# x, y의 값을 동등한 레벨로 해석하고 자 할 때 scaled 옵션을 활용
# 데이터의 표현범위가 틀린 상황에서 동일한 차원으로 데이터를 해석할 때 발생하는 실수를 예방
plt.axis('scaled')

plt.show()

# %% [raw]
# axis() 함수는 아래와 같이 축에 관한 다양한 옵션을 제공합니다.
# 'on' | 'off' | 'equal' | 'scaled' | 'tight' | 'auto' | 'normal' | 'image' | 'square'
# 테스트해 보세요

# %%
### 축의 범위 구하기

# %%
plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')

x_range, y_range = plt.xlim(), plt.ylim()
print(x_range, y_range)

axis_range = plt.axis('scaled')
print(axis_range)
plt.show()
# Out:
# (0.85, 4.15) (1.6, 10.4)
# (0.85, 4.15, 1.6, 10.4)

# %% [markdown]
# ## 선 종류

# %% [markdown]
# ### 기본 방식

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2, 3], [4, 4, 4], '-', color='C0', label='Solid')
plt.plot([1, 2, 3], [3, 3, 3], '--', color='C0', label='Dashed')
plt.plot([1, 2, 3], [2, 2, 2], ':', color='C0', label='Dotted')
plt.plot([1, 2, 3], [1, 1, 1], '-.', color='C0', label='Dash-dot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=4)
plt.show()

# %% [markdown]
# ### linestyle 지정하기

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid', color='C0', label="'solid'")
plt.plot([1, 2, 3], [3, 3, 3], linestyle='dashed', color='C0', label="'dashed'")
plt.plot([1, 2, 3], [2, 2, 2], linestyle='dotted', color='C0', label="'dotted'")
plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashdot', color='C0', label="'dashdot'")
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=4)
plt.show()

# %% [markdown]
# ### 튜플 사용하기

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# linestyle=(0,[첫번째 닷의 길이, 첫번째 닷의 간격, 두번째 닷의 길이, 두번째 닷의 간격])
plt.plot([1, 2, 3], [4, 4, 4], linestyle=(0, (1, 0)), color='C0', label='(0, (1, 1))')
plt.plot([1, 2, 3], [3, 3, 3], linestyle=(0, (1, 5)), color='red', label='(0, (1, 5))')
plt.plot([1, 2, 3], [2, 2, 2], linestyle=(0, (5, 1)), color='blue', label='(0, (5, 1))')
plt.plot([1, 2, 3], [1, 1, 1], linestyle=(0, (3, 5, 1, 5)), color='green', label='(0, (3, 5, 1, 5))')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=2)
plt.show()

# %%
# 튜플의 숫자를 바꿔가며 테스트해보세요.

# %% [markdown]
# ### 선 끝 모양 지정하기

# %% [raw]
# solid_capstyle에 각각 'butt, round’로 지정하면 아래 그림과 같이 뭉뚝한, 둥근 끝 모양이 나타납니다.

# %%
plt.plot([1, 2, 3], [4, 4, 4], linestyle='solid', linewidth=10,
      solid_capstyle='butt', color='C0', label='solid+butt')
plt.plot([1, 2, 3], [3, 3, 3], linestyle='solid', linewidth=10,
      solid_capstyle='round', color='C0', label='solid+round')

plt.plot([1, 2, 3], [2, 2, 2], linestyle='dashed', linewidth=10,
      dash_capstyle='butt', color='C1', label='dashed+butt')
plt.plot([1, 2, 3], [1, 1, 1], linestyle='dashed', linewidth=10,
      dash_capstyle='round', color='C1', label='dashed+round')


plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0.8, 3.2, 0.5, 5.0])
plt.legend(loc='upper right', ncol=2)
plt.show()

# %% [raw]
# 더 다양한 선 종류는 아래 그림을 참고

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 선 종류를 바꿔 가며 테스트 해 보세요.
