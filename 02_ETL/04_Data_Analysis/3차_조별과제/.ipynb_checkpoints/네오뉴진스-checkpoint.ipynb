# %% [markdown]
# # 투자자로써 음원 사업에 투자 하려 할때
# # 피해야 할 상품은 누구인가?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager,rc

import random

font_location = "C:\Windows\Fonts\malgun.ttf"
font_name = font_manager.FontProperties(fname=font_location).get_name()
rc('font',family=font_name)
plt.rcParams['axes.unicode_minus'] = False

# read_csv 함수로 데이터를 Dataframe 형태로 불러옵니다.
file_path = 'data/chipotle.tsv'
chipo = pd.read_csv(file_path, sep = '\t')

# %%
file_path = '../data/musicData2.csv'

musicData = pd.read_csv(file_path,encoding='UTF-8')

# %%
musicData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2178 entries, 0 to 2177
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          2178 non-null   int64
#  1   Month         2178 non-null   int64
#  2   Album Title   2178 non-null   object
#  3   Artist Name   2178 non-null   object
#  4   Genre         2177 non-null   object
#  5   Date          2178 non-null   object
#  6   Distribution  2178 non-null   object
#  7   Rating        2178 non-null   float64
#  8   Music Count   2178 non-null   int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 153.3+ KB

# %% [markdown]
# insight => Year이나 Month가 수치형 데이터로 되어 있다

# %%
musicData.shape
# Out:
# (2178, 9)

# %% [markdown]
# - insight => 데이터 행렬 갯수 파악

# %%
musicData.head(10)
# Out:
#    Year  Month                  Album Title       Artist Name      Genre  \
# 0  2017      1  Boys and Girls Music Vol. 1                샘김     알앤비/어반
# 1  2017      1     여자친구 The 1st Album 'LOL'     여자친구(GFRIEND)         댄스
# 2  2017      1                 Collage (EP)  The Chainsmokers     일렉트로니카
# 3  2017      1                       If You               에일리        발라드
# 4  2017      1                         세 단어              젝스키스        발라드
# 5  2017      1         푸른 바다의 전설 OST Part 1                 린      드라마음악
# 6  2017      1                      신현희와김루트           신현희와김루트  포크,  인디뮤직
# 7  2017      1              도깨비 OST Part 11   Various Artists      드라마음악
# 8  2017      1                   From. 우주소녀              우주소녀         댄스
# 9  2017      1         응답하라 1988 OST Part 2                이적      드라마음악
#
#          Date      Distribution  Rating  Music Count
# 0  2017.01.25         로엔 엔터테인먼트     8.6            2
# 1  2016.07.11          로엔엔터테인먼트     8.1           12
# 2  2016.11.05              소니뮤직     7.5            5
# 3  2016.08.23         로엔 엔터테인먼트     6.9            1
# 4  2016.10.07           YG PLUS     9.0            1
# 5  2016.11.17         로엔 엔터테인먼트     8.1            2
# 6  2015.02.26  Mirrorball Music     8.1            6
# 7  2017.01.09           (주)지니뮤직     8.8            3
# 8  2017.01.04         로엔 엔터테인먼트     8.2            6
# 9  2015.11.07           (주)지니뮤직     8.6            1

# %% [markdown]
# - insight => 상단에 특이 사항 없음

# %%
musicData.tail(10)
# Out:
#       Year  Month               Album Title Artist Name  \
# 2168  2018     10             Present : YOU  GOT7 (갓세븐)
# 2169  2018     10             Present : YOU  GOT7 (갓세븐)
# 2170  2018     10  LOVE YOURSELF 結 ‘Answer’       방탄소년단
# 2171  2018     10             Present : YOU  GOT7 (갓세븐)
# 2172  2018     10             Present : YOU  GOT7 (갓세븐)
# 2173  2018     10                    RECIPE           벤
# 2174  2018     10               Eyes On You  GOT7 (갓세븐)
# 2175  2018     10                      Take    숀(SHAUN)
# 2176  2018     10                   우리 그만하자         로이킴
# 2177  2018     10    하루도 그대를 사랑하지 않은 적이 없었다         임창정
#
#                              Genre        Date Distribution  Rating  \
# 2168  댄스,  발라드,  알앤비/어반,  랩/힙합,  락  2018.09.17      (주)아이리버     8.3
# 2169  댄스,  발라드,  알앤비/어반,  랩/힙합,  락  2018.09.17      (주)아이리버     8.3
# 2170                          랩/힙합  2018.08.24      (주)아이리버     8.4
# 2171  댄스,  발라드,  알앤비/어반,  랩/힙합,  락  2018.09.17      (주)아이리버     8.3
# 2172  댄스,  발라드,  알앤비/어반,  랩/힙합,  락  2018.09.17      (주)아이리버     8.3
# 2173                           발라드  2018.05.08      (주)지니뮤직     7.1
# 2174                   댄스,  알앤비/어반  2018.03.12      (주)아이리버     8.6
# 2175                 일렉트로니카,  인디뮤직  2018.06.27      워너뮤직코리아     3.7
# 2176                           발라드  2018.09.18      (주)지니뮤직     7.0
# 2177                      발라드,  댄스  2018.09.19      (주)인터파크     8.5
#
#       Music Count
# 2168           16
# 2169           16
# 2170           26
# 2171           16
# 2172           16
# 2173           10
# 2174            7
# 2175            4
# 2176            2
# 2177           14

# %% [markdown]
# - insight => 하단에 특이 사항 없음

# %%
musicData.isnull().sum()
# Out:
# Year            0
# Month           0
# Album Title     0
# Artist Name     0
# Genre           1
# Date            0
# Distribution    0
# Rating          0
# Music Count     0
# dtype: int64

# %% [markdown]
# insight => Genre 열에 결측치 1개 확인

# %%
musicData[musicData.Genre.isnull()]
# Out:
#       Year  Month                    Album Title   Artist Name Genre  \
# 1104  2017     12  All I Want For Christmas (EP)  Mariah Carey   NaN
#
#             Date Distribution  Rating  Music Count
# 1104  2007.11.26   Sony Music     8.9            3

# %%
musicData.Genre.value_counts()
# Out:
# 댄스                              548
# 발라드                             409
# 랩/힙합                            300
# 알앤비/어반                          172
# 드라마음악                           141
# 포크                               96
# 팝                                91
# 발라드,  댄스                         89
# 댄스,  발라드                         56
# 발라드,  알앤비/어반                     47
# 댄스,  알앤비/어반                      38
# 댄스,  발라드,  알앤비/어반,  랩/힙합,  락     24
# 락                                21
# 발라드,  락,  포크                     18
# 팝,  얼터너티브 락                      13
# 댄스,  알앤비/어반,  일렉트로니카             13
# 일렉트로니카,  댄스,  알앤비/어반             13
# 발라드,  알앤비/어반,  포크                12
# 일렉트로니카                            9
# 포크,  인디뮤직                         9
# 발라드,  댄스,  알앤비/어반                 8
# 인디뮤직,  포크                         7
# 알앤비/어반,  발라드,  댄스                 6
# 드라마음악,  드라마음악                     5
# 발라드,  재즈                          4
# 인디뮤직,  랩/힙합                       4
# 일렉트로니카,  인디뮤직                     4
# 댄스,  일렉트로니카                       4
# 일렉트로니카,  댄스,  알앤비/어반,  발라드        2
# 클럽/댄스                             2
# TV                                2
# 유럽 음악                             2
# 인디뮤직                              1
# 얼터너티브 락                           1
# 영화음악                              1
# 댄스,  발라드,  랩/힙합,  알앤비/어반          1
# 발라드,  락                           1
# 뮤지컬                               1
# 팝,  캐롤                            1
# 발라드,  댄스,  알앤비/어반,  일렉트로니카        1
# Name: Genre, dtype: int64

# %%
musicData.loc[1104,'Genre'] = '팝,  캐롤'
musicData.loc[1104,'Genre']
# Out:
# '팝,  캐롤'

# %%
musicData.Genre.value_counts()
# Out:
# 댄스                              548
# 발라드                             409
# 랩/힙합                            300
# 알앤비/어반                          172
# 드라마음악                           141
# 포크                               96
# 팝                                91
# 발라드,  댄스                         89
# 댄스,  발라드                         56
# 발라드,  알앤비/어반                     47
# 댄스,  알앤비/어반                      38
# 댄스,  발라드,  알앤비/어반,  랩/힙합,  락     24
# 락                                21
# 발라드,  락,  포크                     18
# 팝,  얼터너티브 락                      13
# 댄스,  알앤비/어반,  일렉트로니카             13
# 일렉트로니카,  댄스,  알앤비/어반             13
# 발라드,  알앤비/어반,  포크                12
# 일렉트로니카                            9
# 포크,  인디뮤직                         9
# 발라드,  댄스,  알앤비/어반                 8
# 인디뮤직,  포크                         7
# 알앤비/어반,  발라드,  댄스                 6
# 드라마음악,  드라마음악                     5
# 발라드,  재즈                          4
# 인디뮤직,  랩/힙합                       4
# 일렉트로니카,  인디뮤직                     4
# 댄스,  일렉트로니카                       4
# 팝,  캐롤                            2
# 일렉트로니카,  댄스,  알앤비/어반,  발라드        2
# 클럽/댄스                             2
# TV                                2
# 유럽 음악                             2
# 얼터너티브 락                           1
# 영화음악                              1
# 인디뮤직                              1
# 댄스,  발라드,  랩/힙합,  알앤비/어반          1
# 발라드,  락                           1
# 뮤지컬                               1
# 발라드,  댄스,  알앤비/어반,  일렉트로니카        1
# Name: Genre, dtype: int64

# %%
musicData.isnull().sum()
# Out:
# Year            0
# Month           0
# Album Title     0
# Artist Name     0
# Genre           0
# Date            0
# Distribution    0
# Rating          0
# Music Count     0
# dtype: int64

# %%
musicData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2178 entries, 0 to 2177
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          2178 non-null   int64
#  1   Month         2178 non-null   int64
#  2   Album Title   2178 non-null   object
#  3   Artist Name   2178 non-null   object
#  4   Genre         2178 non-null   object
#  5   Date          2178 non-null   object
#  6   Distribution  2178 non-null   object
#  7   Rating        2178 non-null   float64
#  8   Music Count   2178 non-null   int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 153.3+ KB

# %%
musicData.head()
# Out:
#    Year  Month                  Album Title       Artist Name   Genre  \
# 0  2017      1  Boys and Girls Music Vol. 1                샘김  알앤비/어반
# 1  2017      1     여자친구 The 1st Album 'LOL'     여자친구(GFRIEND)      댄스
# 2  2017      1                 Collage (EP)  The Chainsmokers  일렉트로니카
# 3  2017      1                       If You               에일리     발라드
# 4  2017      1                         세 단어              젝스키스     발라드
#
#          Date Distribution  Rating  Music Count
# 0  2017.01.25    로엔 엔터테인먼트     8.6            2
# 1  2016.07.11     로엔엔터테인먼트     8.1           12
# 2  2016.11.05         소니뮤직     7.5            5
# 3  2016.08.23    로엔 엔터테인먼트     6.9            1
# 4  2016.10.07      YG PLUS     9.0            1

# %% [markdown]
# - 2017 ~ 2018년 까지 가장 사랑 받은 가수와 장르는 누구일까?
# - 가장 사랑 받지 못한 가수와 장르는 무엇인가?

# %%
musicData['Distribution'].value_counts()
# Out:
# (주)지니뮤직             768
# (주)아이리버             453
# 로엔엔터테인먼트            353
# 로엔 엔터테인먼트           229
# (주)엔에이치엔벅스           78
# 워너뮤직코리아              61
# YG PLUS              46
# 유니버설뮤직               45
# 소니뮤직                 39
# (주)인터파크              16
# 지니뮤직                 16
# (주)뮤직앤뉴              13
# Universal            11
# Mirrorball Music      8
# 퍼플파인 엔터테인먼트           7
# 퍼플파인엔터테인먼트            7
# Sony Music            6
# 다날 엔터테인먼트             6
# (주)미러볼뮤직              6
# (주)루미넌트엔터테인먼트         4
# Warner(Korea)         2
# ㈜인터파크                 2
# (주)벅스                 1
# 포크라노스                 1
# Name: Distribution, dtype: int64

# %%
musicData.loc[musicData['Distribution']=='퍼플파인 엔터테인먼트','Distribution'] = musicData.loc[musicData['Distribution']=='퍼플파인 엔터테인먼트',:].replace('퍼플파인 엔터테인먼트','퍼플파인엔터테인먼트')
musicData.loc[musicData['Distribution']=='로엔 엔터테인먼트','Distribution'] = musicData.loc[musicData['Distribution']=='로엔 엔터테인먼트',:].replace('로엔 엔터테인먼트','로엔엔터테인먼트')
musicData.loc[musicData['Distribution']=='Sony Music','Distribution'] = musicData.loc[musicData['Distribution']=='Sony Music',:].replace('Sony Music','소니뮤직')
musicData.loc[musicData['Distribution']=='Universal','Distribution'] = musicData.loc[musicData['Distribution']=='Universal',:].replace('Universal','유니버설뮤직')
musicData.loc[musicData['Distribution']=='㈜인터파크','Distribution'] = musicData.loc[musicData['Distribution']=='㈜인터파크',:].replace('㈜인터파크','(주)인터파크')
musicData.loc[musicData['Distribution']=='Mirrorball Music','Distribution'] = musicData.loc[musicData['Distribution']=='Mirrorball Music',:].replace('Mirrorball Music','(주)미러볼뮤직')
musicData.loc[musicData['Distribution']=='Warner(Korea)','Distribution'] = musicData.loc[musicData['Distribution']=='Warner(Korea)',:].replace('Warner(Korea)','워너뮤직코리아')
musicData.loc[musicData['Distribution']=='지니뮤직','Distribution'] = musicData.loc[musicData['Distribution']=='지니뮤직',:].replace('지니뮤직','(주)지니뮤직')

# %%
musicData['Distribution'].value_counts()
# Out:
# (주)지니뮤직          784
# 로엔엔터테인먼트         582
# (주)아이리버          453
# (주)엔에이치엔벅스        78
# 워너뮤직코리아           63
# 유니버설뮤직            56
# YG PLUS           46
# 소니뮤직              45
# (주)인터파크           18
# (주)미러볼뮤직          14
# 퍼플파인엔터테인먼트        14
# (주)뮤직앤뉴           13
# 다날 엔터테인먼트          6
# (주)루미넌트엔터테인먼트      4
# (주)벅스              1
# 포크라노스              1
# Name: Distribution, dtype: int64

# %%
musicData_2017 = musicData.loc[musicData['Year']==2017,:].copy()
musicData_2018 = musicData.loc[musicData['Year']==2018,:].copy().reset_index()

# %%
musicData_2017.head()
# Out:
#    Year  Month                  Album Title       Artist Name   Genre  \
# 0  2017      1  Boys and Girls Music Vol. 1                샘김  알앤비/어반
# 1  2017      1     여자친구 The 1st Album 'LOL'     여자친구(GFRIEND)      댄스
# 2  2017      1                 Collage (EP)  The Chainsmokers  일렉트로니카
# 3  2017      1                       If You               에일리     발라드
# 4  2017      1                         세 단어              젝스키스     발라드
#
#          Date Distribution  Rating  Music Count
# 0  2017.01.25     로엔엔터테인먼트     8.6            2
# 1  2016.07.11     로엔엔터테인먼트     8.1           12
# 2  2016.11.05         소니뮤직     7.5            5
# 3  2016.08.23     로엔엔터테인먼트     6.9            1
# 4  2016.10.07      YG PLUS     9.0            1

# %%
musicData_2018.head()
# Out:
#    index  Year  Month                      Album Title Artist Name  \
# 0   1186  2018      1  Red Pill Blues (Deluxe Edition)    Maroon 5
# 1   1187  2018      1                      Be Ordinary         황치열
# 2   1188  2018      1       Universe - 겨울 스페셜 앨범, 2017         EXO
# 3   1189  2018      1                 5집 ANOTHER LIGHT        젝스키스
# 4   1190  2018      1                             세 단어        젝스키스
#
#          Genre        Date Distribution  Rating  Music Count
# 0  팝,  얼터너티브 락  2017.11.03       유니버설뮤직     6.9           21
# 1          발라드  2017.06.13   (주)엔에이치엔벅스     8.5            7
# 2          발라드  2017.12.26      (주)아이리버     8.6            8
# 3          발라드  2017.09.21      (주)지니뮤직     8.5            9
# 4          발라드  2016.10.07      YG PLUS     9.0            1

# %%
Rating_2017_tot = musicData_2017.groupby('Artist Name')['Rating'].mean()
Rating_2017_tot.sort_values(ascending=True).to_frame().head()
# Out:
#                  Rating
# Artist Name
# 문문(MoonMoon)        4.0
# 영비(Young B)         4.2
# 마크툽(Maktub)         5.9
# 민서                  6.4
# 멜로망스(Melomance)     6.7

# %% [markdown]
# - insight => 2017년에 가장 만족도가 적은 가수는 문문

# %%
Rating_2018_tot = musicData_2018.groupby('Artist Name')['Rating'].mean()
Rating_2018_tot.sort_values(ascending=True).to_frame().head()
# Out:
#               Rating
# Artist Name
# 닐로(Nilo)        1.50
# 숀(SHAUN)        3.70
# 문문(MoonMoon)    4.00
# 장덕철             4.70
# 선미              5.83

# %% [markdown]
# - insight => 2018년에 가장 만족도가 적은 가수는 닐로

# %%
Genre_2017_tot = musicData_2017.groupby('Genre')['Rating'].mean()
Genre_2017_tot.sort_values(ascending=True).to_frame().head()
# Out:
#                             Rating
# Genre
# 인디뮤직,  포크                      4.0
# 팝,  얼터너티브 락                    6.9
# 발라드,  댄스,  알앤비/어반,  일렉트로니카     7.0
# 발라드,  재즈                       7.3
# 일렉트로니카                         7.6

# %% [markdown]
# insight => 2017년에 가장 만족도가 적은 장르는 인디뮤직, 포크

# %%
Genre_2018_tot = musicData_2017.groupby('Genre')['Rating'].mean()
Genre_2018_tot.sort_values(ascending=True).to_frame().head()
# Out:
#                             Rating
# Genre
# 인디뮤직,  포크                      4.0
# 팝,  얼터너티브 락                    6.9
# 발라드,  댄스,  알앤비/어반,  일렉트로니카     7.0
# 발라드,  재즈                       7.3
# 일렉트로니카                         7.6

# %% [markdown]
# insight => 2018년에 가장 만족도가 적은 장르는 인디뮤직, 포크

# %%
tot_Rating = pd.concat([Rating_2017_tot,Rating_2018_tot]).to_frame()
tot_Rating = tot_Rating.sort_values(by='Rating',ascending=True)
tot_Rating.head()
# Out:
#               Rating
# Artist Name
# 닐로(Nilo)         1.5
# 숀(SHAUN)         3.7
# 문문(MoonMoon)     4.0
# 문문(MoonMoon)     4.0
# 영비(Young B)      4.2

# %% [markdown]
# - insight => 통합적으로 가장 만족도가 적은 가수는 닐로

# %%
tot_Genre = pd.concat([Genre_2017_tot,Genre_2018_tot]).to_frame()
tot_Genre = tot_Genre.sort_values(by='Rating',ascending=True)
tot_Genre.reset_index(inplace=True)
tot_Genre.head(10)
# Out:
#                         Genre  Rating
# 0                   인디뮤직,  포크     4.0
# 1                   인디뮤직,  포크     4.0
# 2                 팝,  얼터너티브 락     6.9
# 3                 팝,  얼터너티브 락     6.9
# 4  발라드,  댄스,  알앤비/어반,  일렉트로니카     7.0
# 5  발라드,  댄스,  알앤비/어반,  일렉트로니카     7.0
# 6                    발라드,  재즈     7.3
# 7                    발라드,  재즈     7.3
# 8                      일렉트로니카     7.6
# 9                      일렉트로니카     7.6

# %%
df = tot_Genre.head(10)

# %%
worst_bot5 = sns.barplot(data=tot_Genre.head(10),y='Rating',x='Genre')
plt.xticks(rotation = -50)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, '인디뮤직,  포크'),
#   Text(1, 0, '팝,  얼터너티브 락'),
#   Text(2, 0, '발라드,  댄스,  알앤비/어반,  일렉트로니카'),
#   Text(3, 0, '발라드,  재즈'),
#   Text(4, 0, '일렉트로니카')])

# %% [markdown]
# - insight => 통합적으로 가장 만족도가 적은 worst 5 추출 ['인디뮤직,  포크','팝,  얼터너티브 락','발라드,  댄스,  알앤비/어반,  일렉트로니카','발라드,  재즈','일렉트로니카']

# %%
tot_Rating.sort_values(by='Rating',ascending=True)
tot_Rating.reset_index(inplace=True)
tot_Rating
# Out:
#       Artist Name  Rating
# 0        닐로(Nilo)     1.5
# 1        숀(SHAUN)     3.7
# 2    문문(MoonMoon)     4.0
# 3    문문(MoonMoon)     4.0
# 4     영비(Young B)     4.2
# ..            ...     ...
# 243           JBJ     9.7
# 244           남우현     9.7
# 245           Sia     9.8
# 246  David Guetta     9.9
# 247   정키(JungKey)     9.9
#
# [248 rows x 2 columns]

# %%
worst_singer = sns.barplot(data=tot_Rating.head(6),y='Rating',x='Artist Name')

# %% [markdown]
# - insight => 통합적으로 가장 만족도가 적은 worst 5 추출 ['닐로(Nilo)','숀(SHAUN)','문문(MoonMoon)','영비(Young B)','장덕철']

# %% [markdown]
# - 2차 분석
#
# 2017, 2018 두개 concat file에서 Artist_Name, Genre 의 Rating이 가장 낮은 5개 시각화
#
# - Artist_Name bot 5
#
# - Genre bot 5
#
# 포함된 제작사까지 추출
#
# 제작사를 추출하고

# %%
worst = musicData.loc[(musicData['Genre']=='인디뮤직,  포크') &
             (musicData['Genre']=='팝, 얼터너티브 락') |
              (musicData['Genre']=='발라드, 댄스, 알앤비/어반, 일렉트로니카') |
              (musicData['Genre']=='발라드, 재즈') |
              (musicData['Genre']=='일렉트로니카') |
              (musicData['Artist Name']=='닐로(Nilo)') |
              (musicData['Artist Name']=='숀(SHAUN)') |
              (musicData['Artist Name']=='문문(MoonMoon)') |
              (musicData['Artist Name']=='영비(Young B)') |
              (musicData['Artist Name']=='장덕철'), :]
worst
# Out:
#       Year  Month                        Album Title       Artist Name  \
# 2     2017      1                       Collage (EP)  The Chainsmokers
# 128   2017      2                       Collage (EP)  The Chainsmokers
# 220   2017      3  ACT ONE (The Complete Collection)       Marian Hill
# 232   2017      3                       Collage (EP)  The Chainsmokers
# 307   2017      4                       Collage (EP)  The Chainsmokers
# 407   2017      5                       Collage (EP)  The Chainsmokers
# 502   2017      6                       Collage (EP)  The Chainsmokers
# 616   2017      7                                아침에       영비(Young B)
# 618   2017      7                       Collage (EP)  The Chainsmokers
# 691   2017      8                       Collage (EP)  The Chainsmokers
# 1174  2017     12                LIFE IS BEAUTY FULL      문문(MoonMoon)
# 1257  2018      1                               그날처럼               장덕철
# 1283  2018      1                LIFE IS BEAUTY FULL      문문(MoonMoon)
# 1355  2018      2                LIFE IS BEAUTY FULL      문문(MoonMoon)
# 1358  2018      2                               그날처럼               장덕철
# 1450  2018      3                LIFE IS BEAUTY FULL      문문(MoonMoon)
# 1456  2018      3                               그날처럼               장덕철
# 1545  2018      4                LIFE IS BEAUTY FULL      문문(MoonMoon)
# 1554  2018      4                               그날처럼               장덕철
# 1571  2018      4                          About You          닐로(Nilo)
# 1639  2018      5                LIFE IS BEAUTY FULL      문문(MoonMoon)
# 1649  2018      5                               그날처럼               장덕철
# 1652  2018      5                          About You          닐로(Nilo)
# 1730  2018      6                               그날처럼               장덕철
# 1774  2018      6                          About You          닐로(Nilo)
# 1804  2018      7                               그날처럼               장덕철
# 1845  2018      7                          About You          닐로(Nilo)
# 1873  2018      7                               Take          숀(SHAUN)
# 1930  2018      8                               그날처럼               장덕철
# 1968  2018      8                          About You          닐로(Nilo)
# 1979  2018      8                               Take          숀(SHAUN)
# 2019  2018      9                               그날처럼               장덕철
# 2053  2018      9                               Take          숀(SHAUN)
# 2066  2018      9                          About You          닐로(Nilo)
# 2119  2018     10                               그날처럼               장덕철
# 2135  2018     10                          About You          닐로(Nilo)
# 2175  2018     10                               Take          숀(SHAUN)
#
#               Genre        Date Distribution  Rating  Music Count
# 2            일렉트로니카  2016.11.05         소니뮤직     7.5            5
# 128          일렉트로니카  2016.11.05         소니뮤직     7.5            5
# 220          일렉트로니카  2017.04.12       유니버설뮤직     8.4           24
# 232          일렉트로니카  2016.11.05         소니뮤직     7.5            5
# 307          일렉트로니카  2016.11.05         소니뮤직     7.5            5
# 407          일렉트로니카  2016.11.05         소니뮤직     7.5            5
# 502          일렉트로니카  2016.11.05         소니뮤직     7.5            5
# 616            랩/힙합  2017.06.28     로엔엔터테인먼트     4.2            1
# 618          일렉트로니카  2016.11.05         소니뮤직     7.5            5
# 691          일렉트로니카  2016.11.05         소니뮤직     7.5            5
# 1174      인디뮤직,  포크  2016.11.10     (주)미러볼뮤직     4.0            5
# 1257            발라드  2017.11.28     로엔엔터테인먼트     4.7            2
# 1283      인디뮤직,  포크  2016.11.10     (주)미러볼뮤직     4.0            5
# 1355      인디뮤직,  포크  2016.11.10     (주)미러볼뮤직     4.0            5
# 1358            발라드  2017.11.28     로엔엔터테인먼트     4.7            2
# 1450      인디뮤직,  포크  2016.11.10     (주)미러볼뮤직     4.0            5
# 1456            발라드  2017.11.28     로엔엔터테인먼트     4.7            2
# 1545      인디뮤직,  포크  2016.11.10     (주)미러볼뮤직     4.0            5
# 1554            발라드  2017.11.28     로엔엔터테인먼트     4.7            2
# 1571            발라드  2017.10.31   퍼플파인엔터테인먼트     1.5            5
# 1639      인디뮤직,  포크  2016.11.10     (주)미러볼뮤직     4.0            5
# 1649            발라드  2017.11.28     로엔엔터테인먼트     4.7            2
# 1652            발라드  2017.10.31   퍼플파인엔터테인먼트     1.5            5
# 1730            발라드  2017.11.28     로엔엔터테인먼트     4.7            2
# 1774            발라드  2017.10.31   퍼플파인엔터테인먼트     1.5            5
# 1804            발라드  2017.11.28     로엔엔터테인먼트     4.7            2
# 1845            발라드  2017.10.31   퍼플파인엔터테인먼트     1.5            5
# 1873  일렉트로니카,  인디뮤직  2018.06.27      워너뮤직코리아     3.7            4
# 1930            발라드  2017.11.28     로엔엔터테인먼트     4.7            2
# 1968            발라드  2017.10.31   퍼플파인엔터테인먼트     1.5            5
# 1979  일렉트로니카,  인디뮤직  2018.06.27      워너뮤직코리아     3.7            4
# 2019            발라드  2017.11.28     로엔엔터테인먼트     4.7            2
# 2053  일렉트로니카,  인디뮤직  2018.06.27      워너뮤직코리아     3.7            4
# 2066            발라드  2017.10.31   퍼플파인엔터테인먼트     1.5            5
# 2119            발라드  2017.11.28     로엔엔터테인먼트     4.7            2
# 2135            발라드  2017.10.31   퍼플파인엔터테인먼트     1.5            5
# 2175  일렉트로니카,  인디뮤직  2018.06.27      워너뮤직코리아     3.7            4

# %%
distibution_worst = worst['Distribution'].value_counts().reset_index()
distibution_worst.columns=['제작사','worst_count']
distibution_worst
# Out:
#           제작사  worst_count
# 0    로엔엔터테인먼트           11
# 1        소니뮤직            8
# 2  퍼플파인엔터테인먼트            7
# 3    (주)미러볼뮤직            6
# 4     워너뮤직코리아            4
# 5      유니버설뮤직            1

# %%
sns.barplot(data=distibution_worst,y='worst_count',x='제작사')
plt.xticks(rotation=-30)
# Out:
# (array([0, 1, 2, 3, 4, 5]),
#  [Text(0, 0, '로엔엔터테인먼트'),
#   Text(1, 0, '소니뮤직'),
#   Text(2, 0, '퍼플파인엔터테인먼트'),
#   Text(3, 0, '(주)미러볼뮤직'),
#   Text(4, 0, '워너뮤직코리아'),
#   Text(5, 0, '유니버설뮤직')])

# %% [markdown]
# insight => 안좋은 요소를 가지고 있는 값만 보면 로엔에 투자를 하면 안됨

# %%
music_count = musicData.groupby('Distribution')['Music Count'].sum()
music_count = music_count.to_frame().reset_index()
df = music_count.loc[(music_count['Distribution']=='로엔엔터테인먼트')| 
                (music_count['Distribution']=='소니뮤직')|
                (music_count['Distribution']=='퍼플파인엔터테인먼트')|
               (music_count['Distribution']=='(주)미러볼뮤직')|
                (music_count['Distribution']=='워너뮤직코리아')|
               (music_count['Distribution']=='유니버설뮤직'),:
               ]
df.columns = ['제작사','음악 수']
df
# Out:
#            제작사  음악 수
# 2     (주)미러볼뮤직    78
# 10    로엔엔터테인먼트  3034
# 11        소니뮤직   347
# 12     워너뮤직코리아   815
# 13      유니버설뮤직   712
# 14  퍼플파인엔터테인먼트    49

# %%
result = pd.merge(df, distibution_worst, how = 'inner')

result
# Out:
#           제작사  음악 수  worst_count
# 0    (주)미러볼뮤직    78            6
# 1    로엔엔터테인먼트  3034           11
# 2        소니뮤직   347            8
# 3     워너뮤직코리아   815            4
# 4      유니버설뮤직   712            1
# 5  퍼플파인엔터테인먼트    49            7

# %%
result['worst 비율'] = result['worst_count'] / result['음악 수']

# %%
result.sort_values(by='worst 비율',ascending=False)
# Out:
#           제작사  음악 수  worst_count  worst 비율
# 5  퍼플파인엔터테인먼트    49            7  0.142857
# 0    (주)미러볼뮤직    78            6  0.076923
# 2        소니뮤직   347            8  0.023055
# 3     워너뮤직코리아   815            4  0.004908
# 1    로엔엔터테인먼트  3034           11  0.003626
# 4      유니버설뮤직   712            1  0.001404

# %%
plt.style.use('bmh')
plt.rcParams['figure.figsize'] = (9,4)

sns.barplot(data = result, x = '제작사', y = 'worst 비율')
plt.xticks(rotation = -30)

plt.show()

# %% [markdown]
# # insight => 위에 결과에 비해 낸 음악 수에 따라 worst_count를 비율로 잡으면 퍼플파인엔터에 가장 투자를 하면 안됨
