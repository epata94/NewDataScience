# %% [markdown]
# # 지예 & 종민 데이터분석 (책)

# %%
import pandas as pd

# %%
book_data = pd.read_csv("../data/book_data.csv",encoding='euc-kr')

# %%
book_data
# Out:
#              book_name book_writer   book_date book_price book_cover  \
# 0         올 더 빌딩스 인 런던  제임스 걸리버 핸콕  2018-08-25     14,400        양장본
# 1              렛 잇 블리드       이언 랜킨  2018-08-19     13,320       반양장본
# 2            은유로 사회 읽기     대니얼 리그니  2018-08-20     39,500        양장본
# 3             유럽 맥주 여행         백경학  2018-08-24     14,400       반양장본
# 4     이게, 행복이 아니면 무엇이지         김혜령  2018-08-20     13,050        NaN
# ...                ...         ...         ...        ...        ...
# 1995  여기는 함께섬 정치를 배웁니다         최승필  2018-06-01     10,800       반양장본
# 1996     아빠, 이런 여행 어때?         김동옥  2018-05-30     13,500       반양장본
# 1997             생각의 힘    이나모리 가즈오  2018-06-15     12,600        양장본
# 1998      양자 역학이란 무엇인가      마이클 워커  2018-06-04     19,800       반양장본
# 1999            지옥사원 2         네온비  2018-05-30     10,800       반양장본
#
#      book_page  book_size  book_weight book_category book_publisher  \
# 0          140  225*280mm          476       예술/대중문화           책발전소
# ...

# %%
book_data.columns
# Out:
# Index(['book_name', 'book_writer', 'book_date', 'book_price', 'book_cover',
#        'book_page', 'book_size', 'book_weight', 'book_category',
#        'book_publisher', 'sales_point'],
#       dtype='object')

# %%
best_saler=book_data[['book_name','book_publisher', 'sales_point']]

# %%
best_saler
# Out:
#              book_name book_publisher sales_point
# 0         올 더 빌딩스 인 런던           책발전소         110
# 1              렛 잇 블리드          오픈하우스         110
# 2            은유로 사회 읽기     한울(한울아카데미)          10
# 3             유럽 맥주 여행           글항아리          10
# 4     이게, 행복이 아니면 무엇이지            웨일북          10
# ...                ...            ...         ...
# 1995  여기는 함께섬 정치를 배웁니다          천개의바람         770
# 1996     아빠, 이런 여행 어때?          씽크스마트       2,555
# 1997             생각의 힘         한국경제신문       1,305
# 1998      양자 역학이란 무엇인가   처음북스(구 빅슨북스)         915
# 1999            지옥사원 2         위즈덤하우스         705
#
# [2000 rows x 3 columns]

# %%
best_saler['sales_point_분석용']=best_saler['sales_point']
# Out:
# C:\Users\TJ\AppData\Local\Temp\ipykernel_21468\3697977899.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   best_saler['sales_point_분석용']=best_saler['sales_point']

# %%
best_saler
# Out:
#              book_name book_publisher sales_point sales_point_분석용
# 0         올 더 빌딩스 인 런던           책발전소         110             110
# 1              렛 잇 블리드          오픈하우스         110             110
# 2            은유로 사회 읽기     한울(한울아카데미)          10              10
# 3             유럽 맥주 여행           글항아리          10              10
# 4     이게, 행복이 아니면 무엇이지            웨일북          10              10
# ...                ...            ...         ...             ...
# 1995  여기는 함께섬 정치를 배웁니다          천개의바람         770             770
# 1996     아빠, 이런 여행 어때?          씽크스마트       2,555           2,555
# 1997             생각의 힘         한국경제신문       1,305           1,305
# 1998      양자 역학이란 무엇인가   처음북스(구 빅슨북스)         915             915
# 1999            지옥사원 2         위즈덤하우스         705             705
#
# [2000 rows x 4 columns]

# %%
best_saler['sales_point_분석용'] =best_saler.loc[:,'sales_point_분석용'].str.replace(',','').astype('int64')
#best_saler['sales_point_분석용'] = best_saler.loc['sales_point_분석용'].str.replace(',','')
#best_saler
#best_saler.astype({'sales_point_분석용':'int'})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21468\959335269.py in <module>
# ----> 1 best_saler['sales_point_분석용'] =best_saler.loc[:,'sales_point_분석용'].str.replace(',','').astype('int64')
#       2 #best_saler['sales_point_분석용'] = best_saler.loc['sales_point_분석용'].str.replace(',','')
#       3 #best_saler
#       4 #best_saler.astype({'sales_point_분석용':'int'})
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
# ...

# %%
best_saler
# Out:
#              book_name book_publisher sales_point  sales_point_분석용
# 0         올 더 빌딩스 인 런던           책발전소         110              110
# 1              렛 잇 블리드          오픈하우스         110              110
# 2            은유로 사회 읽기     한울(한울아카데미)          10               10
# 3             유럽 맥주 여행           글항아리          10               10
# 4     이게, 행복이 아니면 무엇이지            웨일북          10               10
# ...                ...            ...         ...              ...
# 1995  여기는 함께섬 정치를 배웁니다          천개의바람         770              770
# 1996     아빠, 이런 여행 어때?          씽크스마트       2,555             2555
# 1997             생각의 힘         한국경제신문       1,305             1305
# 1998      양자 역학이란 무엇인가   처음북스(구 빅슨북스)         915              915
# 1999            지옥사원 2         위즈덤하우스         705              705
#
# [2000 rows x 4 columns]

# %%
best_saler.dtypes
# Out:
# book_name         object
# book_publisher    object
# sales_point       object
# dtype: object

# %%
best_saler.astype({'sales_point':'int'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18052\404546148.py in <module>
# ----> 1 best_saler.astype({'sales_point':'int'})
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5896                     res_col = col.copy() if copy else col
#    5897                 else:
# -> 5898                     res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    5899                 results.append(res_col)
#    5900
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# ...
