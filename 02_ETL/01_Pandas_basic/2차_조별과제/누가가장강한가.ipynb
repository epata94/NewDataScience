# %% [markdown]
# # 가장 강한 히어로는 누구인가?
# # Marvel이랑 DC랑 싸우면 누가 이기는가?

# %%
import pandas as pd
import numpy as np

heroInfo = pd.read_csv('../data/HeroInfo.csv',)
heroInfo_df = heroInfo[['Name','Speed','Power','Gender','Publisher']]

# %%
heroInfo_df
# Out:
#                 Name Speed Power  Gender          Publisher
# 0               Zoom   100   100    Male          DC Comics
# 1            Zatanna    25   100  Female          DC Comics
# 2               Yoda    35   100    Male       George Lucas
# 3               Ymir    30   100    Male      Marvel Comics
# 4    Yellowjacket II    35    35  Female      Marvel Comics
# ..               ...   ...   ...     ...                ...
# 743      Abomination    55    65    Male      Marvel Comics
# 744         Abin Sur    55   100    Male          DC Comics
# 745       Abe Sapien    35   100    Male  Dark Horse Comics
# 746           A-Bomb    20    25    Male      Marvel Comics
# 747          3-D Man    45    25    Male      Marvel Comics
#
# [748 rows x 5 columns]

# %%
heroInfo_df.head()
# Out:
#               Name Speed Power  Gender      Publisher
# 0             Zoom   100   100    Male      DC Comics
# 1          Zatanna    25   100  Female      DC Comics
# 2             Yoda    35   100    Male   George Lucas
# 3             Ymir    30   100    Male  Marvel Comics
# 4  Yellowjacket II    35    35  Female  Marvel Comics

# %%
heroInfo_df.count()
# Out:
# Name         748
# Speed        578
# Power        578
# Gender       742
# Publisher    724
# dtype: int64

# %%
heroInfo_df.dtypes
# Out:
# Name         object
# Speed        object
# Power        object
# Gender       object
# Publisher    object
# dtype: object

# %%
heroInfo_df.tail()
# Out:
#             Name Speed Power Gender          Publisher
# 743  Abomination    55    65   Male      Marvel Comics
# 744     Abin Sur    55   100   Male          DC Comics
# 745   Abe Sapien    35   100   Male  Dark Horse Comics
# 746       A-Bomb    20    25   Male      Marvel Comics
# 747      3-D Man    45    25   Male      Marvel Comics

# %%
heroInfo_df.isnull().sum()
# Out:
# Name           0
# Speed        170
# Power        170
# Gender         6
# Publisher     24
# dtype: int64

# %% [markdown]
# ## 결측치 처리

# %%
heroInfo_df['Speed'] = heroInfo_df['Speed'].replace('-','')
heroInfo_df['Speed'] = heroInfo_df['Speed'].replace('',np.nan)

# %%
heroInfo_df['Power'] = heroInfo_df['Power'].replace('-','')
heroInfo_df['Power'] = heroInfo_df['Power'].replace('',np.nan)

# %%
heroInfo_df['Speed'].isnull().sum()
# Out:
# 170

# %%
heroInfo_df['Power'].isnull().sum()
# Out:
# 170

# %%
heroInfo_df = heroInfo_df.dropna()

# %%
heroInfo_df.isnull().sum()
# Out:
# Name         0
# Speed        0
# Power        0
# Gender       0
# Publisher    0
# dtype: int64

# %% [markdown]
# # 수치형 데이터로 변환

# %%
heroInfo_df['Speed'] = heroInfo_df['Speed'].astype(float)
heroInfo_df['Power'] = heroInfo_df['Power'].astype(float)

# %%
heroInfo_df.dtypes
# Out:
# Name          object
# Speed        float64
# Power        float64
# Gender        object
# Publisher     object
# dtype: object

# %%
heroInfo_ex = heroInfo[['Name','Strength']]

# %%
heroInfo_ex.isnull().sum()
# Out:
# Name        0
# Strength    6
# dtype: int64

# %%
heroInfo_ex['Strength'] = heroInfo_ex['Strength'].replace('-','')
heroInfo_ex['Strength'] = heroInfo_ex['Strength'].replace('',np.nan)

# %%
heroInfo_ex = heroInfo_ex.dropna()

# %%
heroInfo_ex.isnull().sum()
# Out:
# Name        0
# Strength    0
# dtype: int64

# %%
heroInfo_ex['Strength'] = heroInfo_ex['Strength'].astype(float)

# %%
heroInfo_df.head()
# Out:
#               Name  Speed  Power  Gender      Publisher
# 0             Zoom  100.0  100.0    Male      DC Comics
# 1          Zatanna   25.0  100.0  Female      DC Comics
# 2             Yoda   35.0  100.0    Male   George Lucas
# 3             Ymir   30.0  100.0    Male  Marvel Comics
# 4  Yellowjacket II   35.0   35.0  Female  Marvel Comics

# %%
heroInfo_ex.head()
# Out:
#               Name  Strength
# 0             Zoom      10.0
# 1          Zatanna      10.0
# 2             Yoda      55.0
# 3             Ymir     100.0
# 4  Yellowjacket II      10.0

# %% [markdown]
# ## Speed, Power 프레임 + Strength 프레임 Name 기준으로 merge

# %%
hero_merge = pd.merge(left = heroInfo_df , right = heroInfo_ex, how = "inner", on = "Name")
hero_merge
# Out:
#                 Name  Speed  Power  Gender          Publisher  Strength
# 0               Zoom  100.0  100.0    Male          DC Comics      10.0
# 1            Zatanna   25.0  100.0  Female          DC Comics      10.0
# 2               Yoda   35.0  100.0    Male       George Lucas      55.0
# 3               Ymir   30.0  100.0    Male      Marvel Comics     100.0
# 4    Yellowjacket II   35.0   35.0  Female      Marvel Comics      10.0
# ..               ...    ...    ...     ...                ...       ...
# 604      Abomination   55.0   65.0    Male      Marvel Comics      80.0
# 605         Abin Sur   55.0  100.0    Male          DC Comics      90.0
# 606       Abe Sapien   35.0  100.0    Male  Dark Horse Comics      30.0
# 607           A-Bomb   20.0   25.0    Male      Marvel Comics     100.0
# 608          3-D Man   45.0   25.0    Male      Marvel Comics      35.0
#
# [609 rows x 6 columns]

# %% [markdown]
# # 강함 요소(Speed,Power,Strength)를 합친 Total 열 추가

# %%
hero_merge['Total'] = hero_merge['Speed'] + hero_merge['Power'] + hero_merge['Strength']
hero_merge
# Out:
#                 Name  Speed  Power  Gender          Publisher  Strength  Total
# 0               Zoom  100.0  100.0    Male          DC Comics      10.0  210.0
# 1            Zatanna   25.0  100.0  Female          DC Comics      10.0  135.0
# 2               Yoda   35.0  100.0    Male       George Lucas      55.0  190.0
# 3               Ymir   30.0  100.0    Male      Marvel Comics     100.0  230.0
# 4    Yellowjacket II   35.0   35.0  Female      Marvel Comics      10.0   80.0
# ..               ...    ...    ...     ...                ...       ...    ...
# 604      Abomination   55.0   65.0    Male      Marvel Comics      80.0  200.0
# 605         Abin Sur   55.0  100.0    Male          DC Comics      90.0  245.0
# 606       Abe Sapien   35.0  100.0    Male  Dark Horse Comics      30.0  165.0
# 607           A-Bomb   20.0   25.0    Male      Marvel Comics     100.0  145.0
# 608          3-D Man   45.0   25.0    Male      Marvel Comics      35.0  105.0
#
# [609 rows x 7 columns]

# %% [markdown]
# # Total을 기반으로 각 히어로들 순위 측정

# %%
hero_merge['rank'] = hero_merge['Total'].rank(method='min',ascending=False).astype(int)

hero_merge.sort_values(by='rank')
# Out:
#                Name  Speed  Power  Gender      Publisher  Strength  Total  \
# 105   Silver Surfer  100.0  100.0    Male  Marvel Comics     100.0  300.0
# 397     General Zod  100.0  100.0    Male      DC Comics     100.0  300.0
# 119          Sentry  100.0  100.0    Male  Marvel Comics     100.0  300.0
# 543        Beyonder  100.0  100.0    Male  Marvel Comics     100.0  300.0
# 572          Ardina  100.0  100.0  Female  Marvel Comics     100.0  300.0
# ..              ...    ...    ...     ...            ...       ...    ...
# 39         Two-Face   15.0   10.0    Male      DC Comics      10.0   35.0
# 8    Wyatt Wingfoot   15.0    5.0    Male  Marvel Comics      10.0   30.0
# 599       Agent Bob   15.0    5.0    Male  Marvel Comics      10.0   30.0
# 75     Stormtrooper   10.0    5.0    Male   George Lucas      10.0   25.0
# 403  Franklin Storm    5.0    0.0       -  Marvel Comics      10.0   15.0
#
#      rank
# 105     1
# 397     1
# 119     1
# 543     1
# 572     1
# ..    ...
# 39    603
# 8     606
# 599   606
# 75    608
# 403   609
#
# [609 rows x 8 columns]

# %%
hero_merge[(hero_merge['rank'] == 1)&(hero_merge['Publisher']=='DC Comics')]
# Out:
#                Name  Speed  Power  Gender  Publisher  Strength  Total  rank
# 57     The Presence  100.0  100.0    Male  DC Comics     100.0  300.0     1
# 70         Superman  100.0  100.0    Male  DC Comics     100.0  300.0     1
# 71        Supergirl  100.0  100.0  Female  DC Comics     100.0  300.0     1
# 72   Superboy-Prime  100.0  100.0    Male  DC Comics     100.0  300.0     1
# 93          Spectre  100.0  100.0    Male  DC Comics     100.0  300.0     1
# 171      Power Girl  100.0  100.0  Female  DC Comics     100.0  300.0     1
# 397     General Zod  100.0  100.0    Male  DC Comics     100.0  300.0     1

# %% [markdown]
# - DC 코믹스에서 가장 강한 영웅들 추출

# %%
hero_merge[(hero_merge['rank'] == 1)&(hero_merge['Publisher']=='Marvel Comics')]
# Out:
#                 Name  Speed  Power  Gender      Publisher  Strength  Total  \
# 105    Silver Surfer  100.0  100.0    Male  Marvel Comics     100.0  300.0
# 119           Sentry  100.0  100.0    Male  Marvel Comics     100.0  300.0
# 188    One-Above-All  100.0  100.0       -  Marvel Comics     100.0  300.0
# 264  Living Tribunal  100.0  100.0       -  Marvel Comics     100.0  300.0
# 543         Beyonder  100.0  100.0    Male  Marvel Comics     100.0  300.0
# 572           Ardina  100.0  100.0  Female  Marvel Comics     100.0  300.0
#
#      rank
# 105     1
# 119     1
# 188     1
# 264     1
# 543     1
# 572     1

# %% [markdown]
# - 마블 코믹스에서 가장 강한 영웅들 추출

# %%
hero_merge['Publisher'].value_counts().nlargest(3).to_frame()
# Out:
#                    Publisher
# Marvel Comics            310
# DC Comics                215
# Dark Horse Comics         17

# %% [markdown]
# - 가장 많은 영웅을 보유하고 있는건 마블 코믹스

# %%
group_cols = ['Publisher']
agg_cols=['Speed','Power','Strength']

# %%
fg = hero_merge.groupby(group_cols)[agg_cols].agg(['sum','min','max','count'])
fg
# Out:
#                      Speed                       Power                      \
#                        sum   min    max count      sum    min    max count
# Publisher
# ABC Studios          100.0  10.0   55.0     4    125.0   15.0   60.0     4
# DC Comics          10255.0  10.0  100.0   215  15850.0   10.0  100.0   215
# Dark Horse Comics    680.0  15.0   95.0    17   1330.0   20.0  100.0    17
# George Lucas         390.0  10.0   50.0    13    830.0    5.0  100.0    13
# IDW Publishing       200.0  50.0   50.0     4    240.0   60.0   60.0     4
# Icon Comics           95.0  15.0   30.0     4    100.0   20.0   30.0     4
# Image Comics         205.0  50.0  100.0     3    270.0   70.0  100.0     3
# J. K. Rowling         25.0  25.0   25.0     1    100.0  100.0  100.0     1
# J. R. R. Tolkien      35.0  35.0   35.0     1    100.0  100.0  100.0     1
# Marvel Comics      12975.0   5.0  100.0   310  20410.0    0.0  100.0   310
# Mattel               120.0  45.0   75.0     2    175.0   75.0  100.0     2
# Microsoft             35.0  35.0   35.0     1     70.0   70.0   70.0     1
# NBC - Heroes         215.0  15.0   35.0    11    740.0   40.0  100.0    11
# Rebellion             40.0  40.0   40.0     1     55.0   55.0   55.0     1
# Shueisha             290.0  35.0   95.0     4    355.0   55.0  100.0     4
# Sony Pictures         95.0  25.0   70.0     2    110.0   10.0  100.0     2
# South Park            85.0  85.0   85.0     1     10.0   10.0   10.0     1
# Star Trek            130.0  20.0   25.0     6    305.0   25.0  100.0     6
# SyFy                  90.0  10.0   35.0     5    265.0   30.0   70.0     5
# Titan Books           20.0  20.0   20.0     1     25.0   25.0   25.0     1
# Universal Studios     25.0  25.0   25.0     1     15.0   15.0   15.0     1
# Wildstorm            110.0  45.0   65.0     2    200.0  100.0  100.0     2
#
#                   Strength
#                        sum    min    max count
# Publisher
# ABC Studios           70.0   10.0   40.0     4
# DC Comics          10870.0    5.0  100.0   215
# Dark Horse Comics    650.0   10.0   85.0    17
# George Lucas         350.0   10.0   55.0    13
# IDW Publishing        70.0   15.0   20.0     4
# Icon Comics           40.0   10.0   10.0     4
# Image Comics         245.0   70.0  100.0     3
# J. K. Rowling         10.0   10.0   10.0     1
# J. R. R. Tolkien      85.0   85.0   85.0     1
# Marvel Comics      14405.0    5.0  100.0   310
# Mattel               200.0  100.0  100.0     2
# Microsoft             75.0   75.0   75.0     1
# NBC - Heroes         180.0   10.0   55.0    11
# Rebellion             20.0   20.0   20.0     1
# Shueisha             380.0   80.0  100.0     4
# Sony Pictures        105.0   15.0   90.0     2
# South Park            10.0   10.0   10.0     1
# Star Trek            105.0   10.0   35.0     6
# SyFy                  65.0    5.0   40.0     5
# Titan Books           15.0   15.0   15.0     1
# Universal Studios     15.0   15.0   15.0     1
# Wildstorm            175.0   80.0   95.0     2

# %% [markdown]
# - 각 출판사 별을 그룹화하여 정보 추출

# %% [markdown]
# - DC 코믹스가 rank 1등 영웅이 한명 더 많지만 전체적인 영웅수가 마블이 훨씬 많다.-\
# - 마블승

# %%
hero_merge.to_csv("hero_rank_service.csv",encoding='UTF-8')
